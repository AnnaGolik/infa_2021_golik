# %%
import os

getway='C:\\Users\\honor\\infa_2021_golik\\2 семестр\\lab8'
where_files = os.listdir(getway)

for file in where_files:
    way, file_type = os.path.splitext(file)
    print(file_type)
    if file_type == '':
        old_name = []
        old_name = file[:2]
        new_name = old_name+'.csv'
        full_old = os.path.join(getway, file) # пропишем старое имя с путём
        full_new = os.path.join(getway, new_name) # пропишем новое имя с путём
        os.rename(full_old, full_new)
os.listdir('C:\\Users\\honor\\infa_2021_golik\\2 семестр\\lab8')
# Out:
# .csv
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .jpeg
# .ipynb
# ['...csv',
#  '0.csv',
#  '01.csv',
#  '02.csv',
#  '03.csv',
#  '04.csv',
#  '05.csv',
#  '06.csv',
#  '07.csv',
#  '08.csv',
#  '09.csv',
#  '10.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '14.csv',
#  '15.csv',
#  '16.csv',
#  '17.csv',
#  '18.csv',
#  '19.csv',
#  '20.csv',
#  '21.csv',
#  '22.csv',
#  '23.csv',
#  '24.csv',
#  '25.csv',
#  '26.csv',
#  '27.csv',
#  '28.csv',
#  '29.csv',
#  '30.csv',
#  '31.csv',
#  '32.csv',
#  '33.csv',
#  '34.csv',
#  '35.csv',
#  '36.csv',
#  '37.csv',
#  '38.csv',
#  '39.csv',
#  'backscreen2.jpeg',
#  'lab8.ipynb']

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

def reading_x (name):
    f=open(name, 'r')
    Flag=True
    x=[]
    for line in f: 
        if Flag==False:
            a=line.split(',')
            x.append(float(a[0]))
        Flag=False
    f.close()  
    return x

def reading_y (mass, name):
    f=open(name, 'r')
    Flag=True
    new_mass=mass
    for line in f: 
        if Flag==False:
            a=line.split(',')
            for i in range (len(mass)):
                new_mass[i].append(float(a[i]))
        Flag=False
    f.close()  
    return new_mass

getway='C:\\Users\\honor\\infa_2021_golik\\2 семестр\\lab8'
where_files = os.listdir(getway)

for file in where_files:
    way, file_type = os.path.splitext(file)
    if file_type == '.csv':
        df = pd.read_csv(file)
        column = df.shape[1]-1
        mass = [[] for i in range(column)]
        x=reading_x(file)
        new_mass = reading_y(mass, file)
        for i in range (len(new_mass)):
            plt.scatter(x, new_mass[i])
            plt.title(file)
        plt.savefig(file+'.png')
        plt.show()

# %%
import os

getway='C:\\Users\\honor\\infa_2021_golik\\2 семестр\\lab8'
folders=[]
files=[]
for item in os.walk(getway):
    wof, folders, files = item
    if files == [] and folders == []:
        print(os.path.basename(wof))
# Out:
# Untitled Folder
# empty folder 2
# super empty folder
